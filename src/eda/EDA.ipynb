# %%
# !pip install protobuf==3.20.3
# !export PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python
# Out:
# Requirement already satisfied: protobuf==3.20.3 in /opt/conda/envs/nyc_airbnb_dev/lib/python3.9/site-packages (3.20.3)

# %%
# !conda install -c conda-forge ydata-profiling -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/nyc_airbnb_dev
#
#   added / updated specs:
#     - ydata-profiling
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     annotated-types-0.7.0      |     pyhd8ed1ab_0          18 KB  conda-forge
#     dacite-1.8.1               |     pyhd8ed1ab_0          19 KB  conda-forge
#     libllvm14-14.0.6           |       hcd5def8_4        30.0 MB  conda-forge
#     llvmlite-0.42.0            |   py39h174d805_1         3.2 MB  conda-forge
#     multimethod-1.11           |     pyhd8ed1ab_1          15 KB  conda-forge
#     numba-0.59.1               |   py39h615d6bd_0         4.1 MB  conda-forge
#     pydantic-2.7.4             |     pyhd8ed1ab_0         275 KB  conda-forge
#     pydantic-core-2.18.4       |   py39ha68c5e3_0         1.5 MB  conda-forge
#     seaborn-base-0.13.0        |     pyhd8ed1ab_0         228 KB  conda-forge
#     typeguard-4.3.0            |     pyhd8ed1ab_0          34 KB  conda-forge
#     visions-0.7.5              |   py39h06a4308_0         125 KB
#     wordcloud-1.9.3            |   py39hd1e30aa_1         179 KB  conda-forge
#     ydata-profiling-4.8.3      |     pyhd8ed1ab_1         200 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        39.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   annotated-types    conda-forge/noarch::annotated-types-0.7.0-pyhd8ed1ab_0
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_0
#   dacite             conda-forge/noarch::dacite-1.8.1-pyhd8ed1ab_0
#   htmlmin            conda-forge/noarch::htmlmin-0.1.12-pyhca7485f_2
#   imagehash          conda-forge/noarch::imagehash-4.3.1-pyhd8ed1ab_0
#   joblib             conda-forge/noarch::joblib-1.4.2-pyhd8ed1ab_0
#   libllvm14          conda-forge/linux-64::libllvm14-14.0.6-hcd5def8_4
#   llvmlite           conda-forge/linux-64::llvmlite-0.42.0-py39h174d805_1
#   multimethod        conda-forge/noarch::multimethod-1.11-pyhd8ed1ab_1
#   networkx           conda-forge/noarch::networkx-3.2-pyhd8ed1ab_0
#   numba              conda-forge/linux-64::numba-0.59.1-py39h615d6bd_0
#   patsy              conda-forge/noarch::patsy-0.5.6-pyhd8ed1ab_0
#   phik               conda-forge/linux-64::phik-0.12.3-py39h992a1cd_1
#   pybind11-abi       conda-forge/noarch::pybind11-abi-4-hd8ed1ab_3
#   pydantic           conda-forge/noarch::pydantic-2.7.4-pyhd8ed1ab_0
#   pydantic-core      conda-forge/linux-64::pydantic-core-2.18.4-py39ha68c5e3_0
#   pywavelets         conda-forge/linux-64::pywavelets-1.4.1-py39h44dd56e_1
#   scipy              conda-forge/linux-64::scipy-1.13.1-py39haf93ffa_0
#   seaborn-base       conda-forge/noarch::seaborn-base-0.13.0-pyhd8ed1ab_0
#   statsmodels        conda-forge/linux-64::statsmodels-0.14.1-py39h44dd56e_0
#   tangled-up-in-uni~ conda-forge/noarch::tangled-up-in-unicode-0.2.0-pyhd8ed1ab_0
#   tqdm               conda-forge/noarch::tqdm-4.66.4-pyhd8ed1ab_0
#   typeguard          conda-forge/noarch::typeguard-4.3.0-pyhd8ed1ab_0
#   visions            pkgs/main/linux-64::visions-0.7.5-py39h06a4308_0
#   wordcloud          conda-forge/linux-64::wordcloud-1.9.3-py39hd1e30aa_1
#   ydata-profiling    conda-forge/noarch::ydata-profiling-4.8.3-pyhd8ed1ab_1
#
#
#
# Downloading and Extracting Packages:
# libllvm14-14.0.6     | 30.0 MB   |                                       |   0%
# numba-0.59.1         | 4.1 MB    |                                       |   0%
#
# llvmlite-0.42.0      | 3.2 MB    |                                       |   0%
#
#
# pydantic-core-2.18.4 | 1.5 MB    |                                       |   0%
#
#
#
# pydantic-2.7.4       | 275 KB    |                                       |   0%
#
#
#
#
# seaborn-base-0.13.0  | 228 KB    |                                       |   0%
#
#
#
#
#
# ydata-profiling-4.8. | 200 KB    |                                       |   0%
#
#
#
#
#
#
# wordcloud-1.9.3      | 179 KB    |                                       |   0%
#
#
#
#
#
#
#
# visions-0.7.5        | 125 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# typeguard-4.3.0      | 34 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# dacite-1.8.1         | 19 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# annotated-types-0.7. | 18 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 30.0 MB   |                                       |   0%
#
# llvmlite-0.42.0      | 3.2 MB    | 1                                     |   0%
#
#
#
# pydantic-2.7.4       | 275 KB    | ##1                                   |   6%
#
#
# pydantic-core-2.18.4 | 1.5 MB    | 3                                     |   1%
# numba-0.59.1         | 4.1 MB    | 1                                     |   0%
#
#
#
#
# libllvm14-14.0.6     | 30.0 MB   | ####6                                 |  12%
#
# llvmlite-0.42.0      | 3.2 MB    | ##################################3   |  93%
#
#
#
#
#
#
# wordcloud-1.9.3      | 179 KB    | ###3                                  |   9%
#
#
#
#
#
# ydata-profiling-4.8. | 200 KB    | ##9                                   |   8%
# numba-0.59.1         | 4.1 MB    | #######################4              |  63%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 30.0 MB   | ###########3                          |  31%
#
#
#
#
#
#
#
#
#
# dacite-1.8.1         | 19 KB     | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
# multimethod-1.11     | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# annotated-types-0.7. | 18 KB     | #################################2    |  90%
#
#
#
#
#
#
#
# visions-0.7.5        | 125 KB    | ####7                                 |  13%
#
#
#
# pydantic-2.7.4       | 275 KB    | ##################################### | 100%
#
#
#
# pydantic-2.7.4       | 275 KB    | ##################################### | 100%
#
#
#
#
# seaborn-base-0.13.0  | 228 KB    | ##################################### | 100%
#
#
#
#
# libllvm14-14.0.6     | 30.0 MB   | #################8                    |  48%
#
#
#
#
#
#
# wordcloud-1.9.3      | 179 KB    | ##################################### | 100%
#
#
#
#
#
#
# wordcloud-1.9.3      | 179 KB    | ##################################### | 100%
#
#
# pydantic-core-2.18.4 | 1.5 MB    | ##################################### | 100%
#
#
# libllvm14-14.0.6     | 30.0 MB   | ##############################6       |  83%
#
#
#
#
#
# ydata-profiling-4.8. | 200 KB    | ##################################### | 100%
#
#
#
#
#
# ydata-profiling-4.8. | 200 KB    | ##################################### | 100%
#
# llvmlite-0.42.0      | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# typeguard-4.3.0      | 34 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# typeguard-4.3.0      | 34 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# dacite-1.8.1         | 19 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# multimethod-1.11     | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# annotated-types-0.7. | 18 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# visions-0.7.5        | 125 KB    | ##################################### | 100%
# visions-0.7.5        | 125 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import wandb
import pandas as pd

run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# wandb: Currently logged in as: radwa (use `wandb login --relogin` to force relogin)
# /opt/conda/envs/nyc_airbnb_dev/lib/python3.9/site-packages/IPython/html.py:12: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   warn("The `IPython.html` package has been deprecated since IPython 4.0. "
# wandb: wandb version 0.17.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">eager-flower-6</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/radwa/nyc_airbnb" target="_blank">https://wandb.ai/radwa/nyc_airbnb</a><br/>
#                 Run page: <a href="https://wandb.ai/radwa/nyc_airbnb/runs/t6xrnum3" target="_blank">https://wandb.ai/radwa/nyc_airbnb/runs/t6xrnum3</a><br/>
#                 Run data is saved locally in <code>/workspaces/nd0821-c2-build-model-workflow-starter/src/eda/wandb/run-20240622_144438-t6xrnum3</code><br/><br/>

# %%
# import pandas_profiling

# profile = pandas_profiling.ProfileReport(df)
# profile.to_widgets()

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %%
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 22984<br/>Program ended successfully.
